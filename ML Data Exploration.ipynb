# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import importlib

from config import *
import data_extraction as d
importlib.reload(d)

FPATH = 'activity_recognition'

# high-level program
if __name__ == '__main__':
    pass
#   data = d.read_file_action('stand', 'pa', path=FPATH)
#   data[['x','y','z']].plot(kind='line')

# %%
"""
Save all actions for each user to a unique file 'activity_recognition/[USER][DEVICE][FNAME]_[ACTION]'.
"""
d.extract_complete_action_seqs('pa', path=FPATH)
# Out:
# identifying samples for action bike for user a
# saved bike data for user a to file
# identifying samples for action sit for user a
# saved sit data for user a to file
# identifying samples for action stand for user a
# saved stand data for user a to file
# identifying samples for action walk for user a
# saved walk data for user a to file
# identifying samples for action stairsup for user a
# saved stairsup data for user a to file
# identifying samples for action stairsdown for user a
# saved stairsdown data for user a to file
# identifying samples for action null for user a
# saved null data for user a to file
# identifying samples for action bike for user b
# saved bike data for user b to file
# identifying samples for action sit for user b
# saved sit data for user b to file
# identifying samples for action stand for user b
# saved stand data for user b to file
# identifying samples for action walk for user b
# saved walk data for user b to file
# ...

# %%
"""
Simple example graph of all three acceleration axes.
"""
data = d.read_file('stand', 'pa', user='a', path=FPATH, device='nexus4_1')
# data.sort_values(by='Index', ascending=True)
data1 = d.read_file('bike', 'pa', user='a', path=FPATH, device='nexus4_1')
data[['x','y','z']].plot(title='User A w/ Nexus4_1, action = stand')
data1[['x','y','z']].plot(title='User A w/ Nexus4_1, action = bike')

# %%
"""
Show all acceleration graphs for each action, separated by user, device.
"""

for user in USERS:
    for device in DEVICES:
        data = d.read_file('stand', 'pa', user=user, path=FPATH, device=device)
        if not data.empty:
            data[['x','y','z']].plot(title=' '.join(['User',user.upper(),'w/',device,', action = stand']))
        else:
            print('EMPTY: User',user.upper(),'w/',device,', action = stand')
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# EMPTY: User d w/ s3mini_2 , action = stand
# EMPTY: User e w/ s3mini_2 , action = stand
# EMPTY: User f w/ s3_1 , action = stand
# EMPTY: User f w/ s3mini_2 , action = stand
# EMPTY: User h w/ s3mini_2 , action = stand
